# %% [markdown]
# # How to start
# In order to get the data, mount your drive (see on the left next to refresh)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/My Drive/home_project/data/Hotel_Reviews.csv")

# %%
print("test")
# Out:
# test

# %%
df
# Out:
#                                             Hotel_Address  ...        lng
# 0        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...  ...   4.915968
# 1        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...  ...   4.915968
# 2        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...  ...   4.915968
# 3        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...  ...   4.915968
# 4        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...  ...   4.915968
# ...                                                   ...  ...        ...
# 515733  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...  ...  16.335677
# 515734  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...  ...  16.335677
# 515735  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...  ...  16.335677
# 515736  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...  ...  16.335677
# 515737  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...  ...  16.335677
#
# [515738 rows x 17 columns]

# %%
df["Review"] = df["Positive_Review"] + df["Negative_Review"]
df = df[["Review","Reviewer_Score"]]
df.head(5)
# Out:
#                                               Review  Reviewer_Score
# 0   Only the park outside of the hotel was beauti...             2.9
# 1   No real complaints the hotel was great great ...             7.5
# 2   Location was good and staff were ok It is cut...             7.1
# 3   Great location in nice surroundings the bar a...             3.8
# 4   Amazing location and building Romantic settin...             6.7
